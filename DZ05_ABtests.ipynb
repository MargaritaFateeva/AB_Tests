# %% [markdown]
# <a href="https://colab.research.google.com/github/MargaritaFateeva/AB_Tests/blob/main/DZ05_ABtests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Урок 5. Применение математической статистики для проверки гипотез в реальной жизни для популярных метрик**
#
# **Задача 1**
#
# Вы провели эксперимент c упрощением формы заказа в магазине Утконос и получили результаты по метрике конверсий в покупку. Выберите метод оценки и оцените есть ли стат.значимые различия между конверсиями в двух группах при alpha = 5%. Дайте краткие рекомендации команде .
#
# Результаты: 1)Число юзеров в группах , которые заходили на сайт в период эксперимента: n1 = 15550 и n2 = 15550 .
#
# 2) Число юзеров в группах , которые совершили хотя бы одну покупку за период эксперимента: n1 = 164 и n2 = 228
#
# 3) Конверсии : conv1 = 1.05% conv2 = 1.47% .

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# Нулевая гипотеза – Между конверсией в двух группах нет статистически значимых различий
# Альтернативная гипотеза – Между конверсией в двух группах есть статистически значимые различия
#
# Строим доверительный интервал на основе Z критерий долей

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy import stats

# %%
n1=15550
n2=15550
a=0.05
buy1 = 164
buy2 = 228
conv1 = 0.0105
conv2 = 0.0147
z=stats.norm.ppf(1-a/2) # тк. двусторонний тест берем a/2
a = (conv2-conv1)-z*np.sqrt(conv1*(1-conv1)/n1 + conv2*(1-conv2)/n2)
b = (conv2-conv1)+z*np.sqrt(conv1*(1-conv1)/n1 + conv2*(1-conv2)/n2)
z
a, b
# Out:
# (0.0017211357671538296, 0.006678864232846168)

# %% [markdown]
# т.к. 0 не входит в интервал для разницы долекй конверсии (т.е. разница отлична от нуля они не совпадают) значит есть статистически значимые различия между конверсиями в двух группах.
# Выкатываем изменения, метрика конвесия в покупку увеличилась

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Калькулятор подтверждает

# %% [markdown]
# **Задача 2**
#
# Сравниваем метрику конверсия в покупку. Размер выборки - 10000 элементов в каждой группе . Какой статистический критерий тут лучше всего подойдёт и почему?

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# Z критерий долей, тк для корректности хи-2 нужна достаточно малый размер выборки

# %%
n1=10000
n2=10000
a=0.05
buy1 = 164
buy2 = 228
convinbuy1 = buy1/n1
convinbuy2 = buy2/n2
z=stats.norm.ppf(1-a/2) # тк. двусторонний тест берем a/2
a = (convinbuy2-convinbuy1)-z*np.sqrt(convinbuy1*(1-convinbuy1)/n1 + convinbuy2*(1-convinbuy2)/n2)
b = (convinbuy2-convinbuy1)+z*np.sqrt(convinbuy1*(1-convinbuy1)/n1 + convinbuy2*(1-convinbuy2)/n2)
z
a, b
# Out:
# (0.002558710593388644, 0.010241289406611355)

# %% [markdown]
# Аналогично, принимаем альтернативную гипотезу
# т.к. 0 не входит в интервал для разницы долекй конверсии (т.е. разница отлична от нуля они не совпадают) значит есть статистически значимые различия между конверсиями в двух группах. Выкатываем изменения, метрика конвесия в покупку увеличилась

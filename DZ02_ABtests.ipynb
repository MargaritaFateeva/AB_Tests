# %% [markdown]
# <a href="https://colab.research.google.com/github/MargaritaFateeva/AB_Tests/blob/main/DZ02_ABtests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание 1**
#
# Сделайте приоритезацию гипотез из предыдущего урока с помощью ICE

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# Гипотезы из домашнего задания 1 для OZON (мобильное приложение и веб-сайт)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Задание 2**
#
# Составьте шаблон дизайна эксперимента для гипотезы, которая набрала больше всего баллов в практическом задании предыдущего урока
#
# Гипотеза:
#
# Что делаем в каждой из групп:
#
# На каких пользователях тестируем:
#
# Метрики:

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# **Гипотеза**: Действие выделить на главной странице на сайте кнопку рассрочку для пользователей всех позволит увеличить метрику количество заказов на величину 7%, потому что привлечет дополнительный сегмент покупателей
#
# **Что делаем в каждой из групп**: Поскольку тест проводится на всех пользователях, авторизованных и неавторизованных есть вероятность совпадения пользователя авторизованного и неавторизованного(не вошел в систему под своим логином) поэтому представленную гипотезу мы можем тестировать только на свех пользоваиелях сразу - для проведения эксперимента нужно использовать метод искусственный контроль.
#
# В данном случае сравниваем показатели: прогнозную метрику количество заказов полученную при постороении модели для случая без воздействия и реальные значения метрики по выборке в случае тестирования гипотезы, а именно введение для всех пользователей изменения, сиситема сплитования в данном случае не нужна
#
# **На каких пользователях тестируем**: все пользователи авторизованные и неавторизованные
#
# **Метрики**: Orders - зколичество заказов

# %% [markdown]
# <a href="https://colab.research.google.com/github/MargaritaFateeva/AB_Tests/blob/main/DZ06_ABtests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Урок 6. Расчёт длительности А/B теста + продвинутые топики**
#
#
# **Задача 1**
#
# Продакт на главной mail.ru решил протестировать в рекомендательной ленте контента вместо карточек со статьями видеоплеер с короткими видео. Нынешний таймспент на юзера в день в среднем равен 25 минут, а стандартная ошибка (SD) равна 156. Мы предполагаем, что в новой версии таймспент на юзера в день изменится на 10%. Средний трафик 20000 человек в день. Посчитайте сколько дней необходимо держать эксперимент при alpha = 5% и beta = 20% .

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# Для непрерывной метрики таймспент на юзера будем использовать критерий для средних значений t-критерий для номального расределения или Манна-Уитни для случая не выполнения условий нормальности.
#
# Для рассчета размера выборки используем калькулятор для непрерывных метрик - таймспент на юзера.
# В данных задачи не указано в какую сторону изменения, предполагаем что время на сайте увеличивается.
# Для рассчета используем абсолютные значения 25*1.1=27.5 - ожидаемое таймспент на юзера.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 77 858*2 = 155 716 размер 2 выборок контрольной группы и тестовой
#
# 155 716 / 20 000 = 7.78 дней
#
# То есть нужно 8 дней для проведения эксперимента

# %% [markdown]
# Ответ: 8 дней

# %% [markdown]
# **Задача 2**
#
# Наша продуктовая команда в ecommerce магазине планирует запустить тест, направленный на ускорение загрузки сайта. Одна из основных метрик bounce rate в GA = 40%. Мы предполагаем, что при оптимизации сайта она изменится минимум на 20%.Средний трафик 4000 человек в день. Посчитайте сколько нам нужно дней держать эксперимент при alpha = 5% и beta = 20%

# %% [markdown]
# РЕШЕНИЕ:

# %% [markdown]
# Bounce Rate — это метрика работы сайта. Она показывает долю посетителей, которые ушли с сайта практически сразу — посмотрев максимум одну страницу.
# Для данной метрики долей будем использовать по аналогии с конверсией рассчет доверительного интервала. Критерии в данном случае Z критерий долей или Хи-квадрат.
#
# Для рассчета размера выборки используем калькулятор для метрик долей.
# В данных задачи не указано в какую сторону изменения, предполагаем что процент отказов на сайте уменьшится.
# Для рассчета используем uplift по условию задачи -20%.
# Проверка: 40%*0.8=32% - абсолютное предполагаемое значение bounce rate
# uplift=(b/a-1)*100%=(32/40-1)*100 = -20% (верно)

# %% [markdown]
# Рассчет для относительного изменения

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Совпадает для абсолютного изменения в -8% (40% - 32%)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 592*2 = 1184 размер 2 выборок контрольной группы и тестовой
#
# 1184 / 4000 = 0,296 дней
#
# То есть нужно 1 день для проведения эксперимента - тк предполагаемый uplift значительный для оценки нужна небольшая выборка

# %% [markdown]
# Ответ: 1 день

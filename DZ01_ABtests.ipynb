# %% [markdown]
# <a href="https://colab.research.google.com/github/MargaritaFateeva/AB_Tests/blob/main/DZ01_ABtests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Урок 1. Формирование гипотез и их скоринг на основе данных**

# %% [markdown]
# **Задание 1** . Выберите любой продукт.
# Например ваш продукт
# ozon.ru
# citilink.ru
# telegram
#
# Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить

# %% [markdown]
# Продукт - веб-сайт и мобильное приложение **OZON**
#
# Ключевые метрики:
#
# **Orders - заказы**.
# Количество заказов на сайте ключевая метрика успешной деятельности маркетплейса, легко измеряемая - например колчиество страниц об успешной оплате заказа.
#
# **Conversion Rate - конверсия**.
# Показатель прироста новых потенциальных покупателей, измеряемая - например количество страниц об успешной регистрации на сайте и в приложении.
#
# **Shopping cart abandonment -брошенные корзины**.
# Показатель который должен конвертироваться в заказ, измеряемый. На данный показатель можно влиять увеличивая количество завершенных заказов.
#
# Все метрики можно измерить

# %% [markdown]
# **Задание 2**. Сформулируйте 5-10 гипотез для выбранного продукта.

# %% [markdown]
# **Действие** по умолчанию выставить сортироку товаров без рекламы/продвижения только по убыванию количество отзывов(или сколько раз купили) **для пользователей** авторизованных **позволит увеличить метрику** количество заказов **на величину** 10%, **потому что** покупатели будут тратить меньше времени на поиск товаров и быстрее делать заказ

# %% [markdown]
# **Действие** кнопку корзина сделать с раскрывающимся окном чтобы видеть товары которые выбраны к покупке **для пользователей** авторизованных **позволит снизить метрику** показатель брошенных корзин **на величину** 2%, **потому что** покупателю будет проще сделать выбор и сравнивать товары

# %% [markdown]
# **Действие** выделить кнопку ВОЙТИ например яркой заливкой **для пользователей** всех **позволит увеличить метрику** конверсия **на величину** 5%, **потому что** станет более заметнее на сайте

# %% [markdown]
# **Действие** ввести систему оповещения при открытии приложения/сайта например открывать брошенную корзину **для пользователей** авторизованных **позволит снизить метрику** количество брошенных корзин **на величину** 2%, **потому что** переключит пользователя с поиска на незавершенный заказ

# %% [markdown]
# **Действие** выделить на главной странице на сайте кнопку рассрочку **для пользователей** всех **позволит увеличить метрику** количество заказов **на величину** 7%, **потому что** привлечет дополнительный сегмент покупателей
